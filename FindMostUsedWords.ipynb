# %% [markdown]
# # What words are most used in poems?
# We will investigate the project Gutenburg corpus of poems to find out. It is assumed that the "quick-experiments" notebook has been run to attain the corpus. Given that this is largely old, we will expand the set of stop-words to account for outdated terms.

# %%
import gzip, json
import re
from collections import Counter
import nltk

# %%
all_lines = []
for line in gzip.open("gutenberg-poetry-v001.ndjson.gz"):
    all_lines.append(json.loads(line.strip()))

# %%
stop_words = set(nltk.corpus.stopwords.words('english')) | set(
    [
        "thy", "thou", "yet", "thee", "thus", "like", "shall", "upon", "would", "let", 
        "us", "me", "come", "could","though", "must", "may", ".", "'tis", "go", "hath", 
        "ye", "came", "/", "o'", "--", "i'll", "i'm", "'twas", "there's", "th'", "'til",
        "o'er", "till"
    ]
)

# %%
line_text = [line["s"].lower().replace(",", "").replace('"', "") for line in all_lines]
split_line = " ".join(line_text).split()

# %%
split_line = [line for line in split_line if line not in stop_words]

# %%
counts = Counter(split_line).most_common(300)
counts
# Out:
# [('one', 54569),
#  ('love', 39450),
#  ('heart', 29736),
#  ('see', 28616),
#  ('still', 28527),
#  ('man', 27023),
#  ('little', 26744),
#  ('old', 26182),
#  ('day', 25648),
#  ('never', 24271),
#  ('eyes', 24136),
#  ('life', 23709),
#  ('long', 23444),
#  ('said', 22054),
#  ('great', 21736),
#  ('men', 20648),
#  ('made', 20100),
#  ('know', 19896),
#  ('god', 19842),
#  ('sweet', 19719),
#  ('night', 19543),
#  ('whose', 19309),
#  ('light', 19124),
#  ('many', 19047),
#  ('every', 18891),
#  ('time', 18501),
#  ('good', 18360),
#  ('far', 18136),
#  ('first', 18052),
#  ('fair', 17470),
#  ('hand', 17304),
#  ('well', 17301),
#  ('make', 16645),
#  ('ever', 16511),
#  ('earth', 16351),
#  ('might', 16220),
#  ('world', 16063),
#  ('soul', 15809),
#  ("an'", 15551),
#  ('round', 14777),
#  ('last', 14712),
#  ('saw', 14584),
#  ('say', 13879),
#  ('away', 13745),
#  ('high', 13615),
#  ('face', 13613),
#  ('death', 13533),
#  ('sun', 13270),
#  ('back', 13258),
#  ('king', 13245),
#  ('thought', 13087),
#  ('way', 13002),
#  ('take', 12986),
#  ('give', 12752),
#  ('two', 12629),
#  ('heaven', 12624),
#  ('white', 12606),
#  ('heard', 12584),
#  ('full', 12397),
#  ('tell', 12387),
#  ('things', 12203),
#  ('dear', 12115),
#  ('hear', 12007),
#  ('oh', 11667),
#  ('within', 11560),
#  ('head', 11426),
#  ('much', 11308),
#  ('art', 11267),
#  ('bright', 11259),
#  ('left', 11215),
#  ('went', 11123),
#  ('even', 11069),
#  ('look', 10960),
#  ('sea', 10927),
#  ('forth', 10898),
#  ('words', 10773),
#  ('without', 10755),
#  ('deep', 10718),
#  ('land', 10701),
#  ('young', 10645),
#  ('think', 10591),
#  ('son', 10577),
#  ('lord', 10527),
#  ('new', 10223),
#  ('dark', 10191),
#  ('find', 10103),
#  ('lay', 9998),
#  ('voice', 9973),
#  ('dead', 9914),
#  ('name', 9907),
#  ('hands', 9882),
#  ('beneath', 9841),
#  ('place', 9817),
#  ('soon', 9738),
#  ('home', 9524),
#  ('air', 9517),
#  ('unto', 9508),
#  ('found', 9478),
#  ('mine', 9447),
#  ('song', 9413),
#  ('stood', 9364),
#  ('wild', 9321),
#  ('joy', 9288),
#  ('days', 9283),
#  ('wind', 9238),
#  ('alone', 9237),
#  ('years', 9201),
#  ('golden', 9032),
#  ('doth', 9023),
#  ('de', 8956),
#  ('since', 8955),
#  ('set', 8843),
#  ('among', 8718),
#  ('thine', 8712),
#  ('green', 8693),
#  ('rest', 8667),
#  ('ere', 8644),
#  ('mother', 8614),
#  ('fire', 8613),
#  ('feet', 8588),
#  ('hope', 8542),
#  ('mind', 8488),
#  ('rose', 8485),
#  ('right', 8484),
#  ('true', 8479),
#  ('gave', 8435),
#  ('poor', 8392),
#  ('spirit', 8135),
#  ('eye', 8100),
#  ('side', 8096),
#  ('gold', 7986),
#  ('red', 7946),
#  ('fear', 7910),
#  ('knew', 7903),
#  ('near', 7847),
#  ('arms', 7788),
#  ('seen', 7767),
#  ('mighty', 7761),
#  ('beauty', 7742),
#  ('none', 7699),
#  ('blood', 7574),
#  ('best', 7566),
#  ('fell', 7561),
#  ('comes', 7547),
#  ('around', 7541),
#  ('thing', 7513),
#  ('tears', 7430),
#  ('power', 7413),
#  ('leave', 7384),
#  ('along', 7310),
#  ('took', 7306),
#  ('soft', 7297),
#  ('word', 7285),
#  ('bring', 7201),
#  ('happy', 7155),
#  ('sing', 7154),
#  ('three', 7073),
#  ('me.', 7072),
#  ('hast', 7067),
#  ('father', 7062),
#  ('hour', 7030),
#  ('call', 7020),
#  ('live', 7007),
#  ('lost', 7003),
#  ('cold', 6938),
#  ('keep', 6927),
#  ('cannot', 6896),
#  ('sky', 6887),
#  ('lips', 6868),
#  ('sad', 6795),
#  ('child', 6708),
#  ('strong', 6686),
#  ('stand', 6651),
#  ('house', 6634),
#  ('flowers', 6623),
#  ('sleep', 6611),
#  ('another', 6607),
#  ('blue', 6595),
#  ('sound', 6586),
#  ('fall', 6575),
#  ('care', 6535),
#  ('bear', 6457),
#  ('peace', 6422),
#  ('breast', 6420),
#  ('stars', 6412),
#  ('half', 6383),
#  ('black', 6381),
#  ('leaves', 6340),
#  ('better', 6246),
#  ('sight', 6237),
#  ('turn', 6230),
#  ('gods', 6221),
#  ('hearts', 6215),
#  ('glory', 6202),
#  ('youth', 6190),
#  ('meet', 6150),
#  ('nothing', 6143),
#  ('morning', 6132),
#  ('truth', 6106),
#  ('brought', 6104),
#  ('free', 6085),
#  ('nature', 6074),
#  ('friend', 6068),
#  ('vain', 6056),
#  ('wide', 6050),
#  ('people', 6040),
#  ('low', 6018),
#  ('gone', 6006),
#  ('done', 5993),
#  ('work', 5975),
#  ('ah', 5966),
#  ('moon', 5944),
#  ('past', 5942),
#  ('water', 5902),
#  ('part', 5847),
#  ('holy', 5825),
#  ('dream', 5814),
#  ('hold', 5813),
#  ('loved', 5805),
#  ('pass', 5787),
#  ('close', 5702),
#  ('lady', 5684),
#  ('save', 5651),
#  ('children', 5642),
#  ('grace', 5607),
#  ('behind', 5604),
#  ('lie', 5583),
#  ('summer', 5575),
#  ('less', 5559),
#  ('clear', 5550),
#  ('human', 5518),
#  ('oft', 5507),
#  ('music', 5504),
#  ('beyond', 5489),
#  ('speak', 5475),
#  ('end', 5462),
#  ('breath', 5453),
#  ('silent', 5452),
#  ('lies', 5436),
#  ('strange', 5433),
#  ('feel', 5430),
#  ('beside', 5429),
#  ('spring', 5418),
#  ('noble', 5403),
#  ('die', 5393),
#  ('put', 5384),
#  ('seemed', 5350),
#  ('makes', 5337),
#  ('turned', 5297),
#  ('kind', 5287),
#  ('thousand', 5272),
#  ('sorrow', 5244),
#  ('hair', 5236),
#  ('pain', 5230),
#  ('thoughts', 5192),
#  ('war', 5188),
#  ('rise', 5158),
#  ('held', 5132),
#  ('et', 5106),
#  ('fate', 5079),
#  ('form', 5066),
#  ('friends', 5033),
#  ('told', 5015),
#  ('winds', 4997),
#  ('ancient', 4997),
#  ('wise', 4991),
#  ('next', 4983),
#  ('silver', 4973),
#  ('hard', 4967),
#  ('spake', 4965),
#  ('gentle', 4957),
#  ('pale', 4941),
#  ('body', 4919),
#  ('seems', 4919),
#  ('across', 4914),
#  ('sat', 4904),
#  ('living', 4863),
#  ('smile', 4856),
#  ('pride', 4846),
#  ('wings', 4811),
#  ('sir', 4799),
#  ("ne'er", 4772),
#  ('weary', 4764),
#  ('brave', 4759),
#  ('behold', 4742),
#  ('cried', 4737),
#  ('trees', 4735),
#  ('proud', 4734),
#  ('strength', 4733),
#  ('rich', 4726),
#  ('seek', 4699),
#  ('city', 4664),
#  ('laid', 4662),
#  ('small', 4631),
#  ('looked', 4620),
#  ('shore', 4617),
#  ('waves', 4609),
#  ('others', 4600),
#  ('tree', 4594),
#  ('faith', 4592)]

# %%
print("\n".join([count[0] for count in counts[:25]]))
# Out:
# one
# love
# heart
# see
# still
# man
# little
# old
# day
# never
# eyes
# life
# long
# said
# great
# men
# made
# know
# god
# sweet
# night
# whose
# light
# many
# every
